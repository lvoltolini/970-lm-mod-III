# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %%time

ar = np.array(range(100))

for i in range(len(ar)):
    if ar[i]%2 == 0:
        ar[i] = i**2
    else: ar[i] = 0
ar
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# array([   0,    0,    4,    0,   16,    0,   36,    0,   64,    0,  100,
#           0,  144,    0,  196,    0,  256,    0,  324,    0,  400,    0,
#         484,    0,  576,    0,  676,    0,  784,    0,  900,    0, 1024,
#           0, 1156,    0, 1296,    0, 1444,    0, 1600,    0, 1764,    0,
#        1936,    0, 2116,    0, 2304,    0, 2500,    0, 2704,    0, 2916,
#           0, 3136,    0, 3364,    0, 3600,    0, 3844,    0, 4096,    0,
#        4356,    0, 4624,    0, 4900,    0, 5184,    0, 5476,    0, 5776,
#           0, 6084,    0, 6400,    0, 6724,    0, 7056,    0, 7396,    0,
#        7744,    0, 8100,    0, 8464,    0, 8836,    0, 9216,    0, 9604,
#           0])

# %%
# %%time

ar = np.array(range(100))

for i in range(len(ar)):
    if ar[i]%2 == 0:
        ar[i] = i**2
    else: ar[i] = 0
ar
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# array([   0,    0,    4,    0,   16,    0,   36,    0,   64,    0,  100,
#           0,  144,    0,  196,    0,  256,    0,  324,    0,  400,    0,
#         484,    0,  576,    0,  676,    0,  784,    0,  900,    0, 1024,
#           0, 1156,    0, 1296,    0, 1444,    0, 1600,    0, 1764,    0,
#        1936,    0, 2116,    0, 2304,    0, 2500,    0, 2704,    0, 2916,
#           0, 3136,    0, 3364,    0, 3600,    0, 3844,    0, 4096,    0,
#        4356,    0, 4624,    0, 4900,    0, 5184,    0, 5476,    0, 5776,
#           0, 6084,    0, 6400,    0, 6724,    0, 7056,    0, 7396,    0,
#        7744,    0, 8100,    0, 8464,    0, 8836,    0, 9216,    0, 9604,
#           0])

# %%
# %%time
plt.figure()
plt.plot(ar)
plt.show()
# Out:
# CPU times: total: 46.9 ms
# Wall time: 130 ms
